# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib
data_dir = 'C:\\Users\\starl\\Downloads\\class\\data'
data_dir = pathlib.Path(data_dir).with_suffix('')

# %%
data_dir
# Out:
# WindowsPath('C:/Users/starl/Downloads/class/data')

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# 데이터 사본의 총 개수
# Out:
# 25000

# %%
cats = list(data_dir.glob('cat/*'))
PIL.Image.open(str(cats[3]))
# 고양이
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=403x499>

# %%
dogs = list(data_dir.glob('dog/*'))
PIL.Image.open(str(dogs[3]))
# 강아지
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x397>

# %%
# 데이터셋 생성 ( 매개변수 지정 )
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# class ( 폴더명 )
# Out:
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
